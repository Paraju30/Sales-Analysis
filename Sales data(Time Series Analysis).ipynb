# %% [markdown]
# ### Sales data

# %%
pip install pmdarima

# %%
## importing the require libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
## import the dataset
data = pd.read_excel ('E:/New folder/Sales data/New Microsoft Excel Worksheet.xlsx')

# %%
data
# Out:
#        Months       Sales
# 0       April   635653.37
# 1         May   700311.48
# 2        June   470604.53
# 3        July   597186.67
# 4      August   604405.35
# 5   September   684790.95
# 6     October  1258909.94
# 7    November   927700.19
# 8    December   725149.21
# 9     January   602462.44
# 10   February   497088.04
# 11      March   794466.59
# 12      April  8498728.76
# 13        May  1192360.18
# 14       June   691180.16
# 15       July   846998.43
# 16     August  1253428.91
# 17  September   399026.84
# 18    October  1673517.75
# 19   November   880229.03
# 20   December   868266.45
# 21    January   733336.39
# 22   February   839719.54
# 23      March   691415.80
# 24      April    -1267.93
# 25        May   299149.31
# 26       June   428675.78
# 27       July   500350.33
# 28     August   463945.71
# 29  September   643113.17
# 30    October  1579851.92
# 31   November  1783348.18
# 32   December   349216.35
# 33    January  1054289.53
# ...

# %%
data.head()
# Out:
#    Months      Sales
# 0   April  635653.37
# 1     May  700311.48
# 2    June  470604.53
# 3    July  597186.67
# 4  August  604405.35

# %%
df = pd.DataFrame(data[['Months','Sales']])

# %%
df
# Out:
#        Months       Sales
# 0       April   635653.37
# 1         May   700311.48
# 2        June   470604.53
# 3        July   597186.67
# 4      August   604405.35
# 5   September   684790.95
# 6     October  1258909.94
# 7    November   927700.19
# 8    December   725149.21
# 9     January   602462.44
# 10   February   497088.04
# 11      March   794466.59
# 12      April  8498728.76
# 13        May  1192360.18
# 14       June   691180.16
# 15       July   846998.43
# 16     August  1253428.91
# 17  September   399026.84
# 18    October  1673517.75
# 19   November   880229.03
# 20   December   868266.45
# 21    January   733336.39
# 22   February   839719.54
# 23      March   691415.80
# 24      April    -1267.93
# 25        May   299149.31
# 26       June   428675.78
# 27       July   500350.33
# 28     August   463945.71
# 29  September   643113.17
# 30    October  1579851.92
# 31   November  1783348.18
# 32   December   349216.35
# 33    January  1054289.53
# ...

# %%
## checking the null values present or not
data.isnull().sum()
# Out:
# Months    0
# Sales     0
# dtype: int64

# %%
data
# Out:
#        Months       Sales
# 0       April   635653.37
# 1         May   700311.48
# 2        June   470604.53
# 3        July   597186.67
# 4      August   604405.35
# 5   September   684790.95
# 6     October  1258909.94
# 7    November   927700.19
# 8    December   725149.21
# 9     January   602462.44
# 10   February   497088.04
# 11      March   794466.59
# 12      April  8498728.76
# 13        May  1192360.18
# 14       June   691180.16
# 15       July   846998.43
# 16     August  1253428.91
# 17  September   399026.84
# 18    October  1673517.75
# 19   November   880229.03
# 20   December   868266.45
# 21    January   733336.39
# 22   February   839719.54
# 23      March   691415.80
# 24      April    -1267.93
# 25        May   299149.31
# 26       June   428675.78
# 27       July   500350.33
# 28     August   463945.71
# 29  September   643113.17
# 30    October  1579851.92
# 31   November  1783348.18
# 32   December   349216.35
# 33    January  1054289.53
# ...

# %%
data.isnull().sum()
# Out:
# Months    0
# Sales     0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %%
Mon = data['Months']
Sale = data['Sales']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
plt.plot(Mon,Sale,label="months vs sales")
plt.title("Trend of Sales")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.legend()
plt.xticks(rotation=45)

plt.show()

# %%
data.shape
# Out:
# (48, 2)

# %%
data = pd.read_excel ('E:/New folder/Sales data/New Microsoft Excel Worksheet.xlsx',header= 0,  index_col="Months")
data.head()
# Out:
#             Sales
# Months
# April   635653.37
# May     700311.48
# June    470604.53
# July    597186.67
# August  604405.35

# %%
data.index
# Out:
# Index(['April', 'May', 'June', 'July', 'August', 'September', 'October',
#        'November', 'December', 'January', 'February', 'March', 'April', 'May',
#        'June', 'July', 'August', 'September', 'October', 'November',
#        'December', 'January', 'February', 'March', 'April', 'May', 'June',
#        'July', 'August', 'September', 'October', 'November', 'December',
#        'January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December', 'January',
#        'February', 'March'],
#       dtype='object', name='Months')

# %% [markdown]
# ### Scatter plot for sales

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# Add x-axis and y-axis
ax.scatter(data.index.values,
           data['Sales'],
           color='purple')

# Set title and labels for axes
ax.set(xlabel="Months",
       ylabel="Sales",
       title="Scatter plot for Sales")

plt.show()

# %%
df = data['Sales']
df
# Out:
# Months
# April         635653.37
# May           700311.48
# June          470604.53
# July          597186.67
# August        604405.35
# September     684790.95
# October      1258909.94
# November      927700.19
# December      725149.21
# January       602462.44
# February      497088.04
# March         794466.59
# April        8498728.76
# May          1192360.18
# June          691180.16
# July          846998.43
# August       1253428.91
# September     399026.84
# October      1673517.75
# November      880229.03
# December      868266.45
# January       733336.39
# February      839719.54
# March         691415.80
# April          -1267.93
# May           299149.31
# June          428675.78
# July          500350.33
# August        463945.71
# September     643113.17
# October      1579851.92
# November     1783348.18
# December      349216.35
# January      1054289.53
# February      812457.17
# March         789835.31
# April         198025.43
# May            66303.21
# ...

# %% [markdown]
# ### Lag plot for sales

# %%
import statsmodels.tsa.api as smt

smt.stattools.acovf(df[:50])
# Out:
# array([ 1.37083796e+12,  8.13760993e+10, -7.71523372e+10, -4.92162698e+10,
#         2.85435074e+10, -9.32288376e+10,  1.22973198e+11, -4.88167591e+10,
#        -4.54120233e+10, -7.23047494e+10, -7.28621103e+10, -3.66299628e+10,
#        -1.22876368e+11, -6.35917654e+10, -9.00002728e+10, -3.14123936e+10,
#        -6.64923252e+10, -3.46992977e+10,  9.56642655e+10,  1.39403042e+11,
#        -7.57806889e+10,  2.31304326e+10, -6.25275086e+09, -4.92968113e+08,
#        -7.79920118e+10, -1.19914123e+11, -5.85316899e+10, -4.67865271e+10,
#        -1.53859129e+10,  1.22951140e+10,  1.17421308e+11,  1.64853745e+10,
#        -7.14935701e+10, -6.47284598e+10,  7.64519505e+10,  1.25735846e+10,
#         2.27760660e+10,  9.04796705e+09, -4.26077281e+09, -4.02447358e+09,
#         9.91100854e+08, -1.26959137e+09,  5.74926750e+08,  3.84322023e+09,
#         2.12504023e+09,  1.88447582e+09, -1.86117588e+09,  4.90536611e+08])

# %%
lags = [5,10,]
for l in lags:
    titles = "Autocorrelation with lags "+ str(l)
    smt.graphics.plot_acf(df,lags=l,alpha=0.05,title=titles)

# %%
lags = [5,10,]
for l in lags:
    titles = "Partial Autocorrelation with lags "+ str(l)
    smt.graphics.plot_pacf(df,lags=l,alpha=0.05,title=titles)
# Out:
# C:\Users\DS_USER\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# C:\Users\DS_USER\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# ### Checking the Stationarity of Time Series Data
#
# Dickey Fuller test:
#
# H0 : Time Series is Non Stationary
#
# H1: Time Series is Stationary

# %%
from statsmodels.tsa.stattools import adfuller
print("Observations of Dickey-fuller test")
data1 = data
dftest = adfuller(data1['Sales'],autolag='AIC')
dfoutput=pd.Series(dftest[0:4],index=['Test Statistic','p-value','#lags used','number of observations used'])
for key,value in dftest[4].items():
    dfoutput['critical value (%s)'%key]= value
print(dfoutput)
# Out:
# Observations of Dickey-fuller test
# Test Statistic                -6.325127e+00
# p-value                        2.999414e-08
# #lags used                     0.000000e+00
# number of observations used    4.700000e+01
# critical value (1%)           -3.577848e+00
# critical value (5%)           -2.925338e+00
# critical value (10%)          -2.600774e+00
# dtype: float64

# %% [markdown]
# From adffuller test, we can see that we fail to reject the null hypothesis. So, the data set is non stationary.

# %%
df
# Out:
# Months
# April         635653.37
# May           700311.48
# June          470604.53
# July          597186.67
# August        604405.35
# September     684790.95
# October      1258909.94
# November      927700.19
# December      725149.21
# January       602462.44
# February      497088.04
# March         794466.59
# April        8498728.76
# May          1192360.18
# June          691180.16
# July          846998.43
# August       1253428.91
# September     399026.84
# October      1673517.75
# November      880229.03
# December      868266.45
# January       733336.39
# February      839719.54
# March         691415.80
# April          -1267.93
# May           299149.31
# June          428675.78
# July          500350.33
# August        463945.71
# September     643113.17
# October      1579851.92
# November     1783348.18
# December      349216.35
# January      1054289.53
# February      812457.17
# March         789835.31
# April         198025.43
# May            66303.21
# ...

# %%
daT = df.reset_index()
daT.head()
# Out:
#    Months      Sales
# 0   April  635653.37
# 1     May  700311.48
# 2    June  470604.53
# 3    July  597186.67
# 4  August  604405.35

# %%
df = daT.set_index('Months')
df
# Out:
#                                   Sales
# Months
# April     1970-01-01 00:00:00.000635653
# May       1970-01-01 00:00:00.000700311
# June      1970-01-01 00:00:00.000470604
# July      1970-01-01 00:00:00.000597186
# August    1970-01-01 00:00:00.000604405
# September 1970-01-01 00:00:00.000684790
# October   1970-01-01 00:00:00.001258909
# November  1970-01-01 00:00:00.000927700
# December  1970-01-01 00:00:00.000725149
# January   1970-01-01 00:00:00.000602462
# February  1970-01-01 00:00:00.000497088
# March     1970-01-01 00:00:00.000794466
# April     1970-01-01 00:00:00.008498728
# May       1970-01-01 00:00:00.001192360
# June      1970-01-01 00:00:00.000691180
# July      1970-01-01 00:00:00.000846998
# August    1970-01-01 00:00:00.001253428
# September 1970-01-01 00:00:00.000399026
# October   1970-01-01 00:00:00.001673517
# November  1970-01-01 00:00:00.000880229
# December  1970-01-01 00:00:00.000868266
# January   1970-01-01 00:00:00.000733336
# ...

# %% [markdown]
# ### Decomposing TheTime Series Data

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_result = seasonal_decompose(df.Sales, model='additive', period = 1)

fig = decompose_result.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()

# %%
decompose_result.resid
# Out:
# Months
# April        0.0
# May          0.0
# June         0.0
# July         0.0
# August       0.0
# September    0.0
# October      0.0
# November     0.0
# December     0.0
# January      0.0
# February     0.0
# March        0.0
# April        0.0
# May          0.0
# June         0.0
# July         0.0
# August       0.0
# September    0.0
# October      0.0
# November     0.0
# December     0.0
# January      0.0
# February     0.0
# March        0.0
# April        0.0
# May          0.0
# June         0.0
# July         0.0
# August       0.0
# September    0.0
# October      0.0
# November     0.0
# December     0.0
# January      0.0
# February     0.0
# March        0.0
# April        0.0
# May          0.0
# June         0.0
# July         0.0
# August       0.0
# September    0.0
# October      0.0
# November     0.0
# December     0.0
# January      0.0
# February     0.0
# March        0.0
# Name: resid, dtype: float64

# %%
decompose_result.seasonal
# Out:
# Months
# April        0.0
# May          0.0
# June         0.0
# July         0.0
# August       0.0
# September    0.0
# October      0.0
# November     0.0
# December     0.0
# January      0.0
# February     0.0
# March        0.0
# April        0.0
# May          0.0
# June         0.0
# July         0.0
# August       0.0
# September    0.0
# October      0.0
# November     0.0
# December     0.0
# January      0.0
# February     0.0
# March        0.0
# April        0.0
# May          0.0
# June         0.0
# July         0.0
# August       0.0
# September    0.0
# October      0.0
# November     0.0
# December     0.0
# January      0.0
# February     0.0
# March        0.0
# April        0.0
# May          0.0
# June         0.0
# July         0.0
# August       0.0
# September    0.0
# October      0.0
# November     0.0
# December     0.0
# January      0.0
# February     0.0
# March        0.0
# Name: seasonal, dtype: float64

# %%
decompose_result.trend
# Out:
# Months
# April         635653.0
# May           700311.0
# June          470604.0
# July          597186.0
# August        604405.0
# September     684790.0
# October      1258909.0
# November      927700.0
# December      725149.0
# January       602462.0
# February      497088.0
# March         794466.0
# April        8498728.0
# May          1192360.0
# June          691180.0
# July          846998.0
# August       1253428.0
# September     399026.0
# October      1673517.0
# November      880229.0
# December      868266.0
# January       733336.0
# February      839719.0
# March         691415.0
# April          -1267.0
# May           299149.0
# June          428675.0
# July          500350.0
# August        463945.0
# September     643113.0
# October      1579851.0
# November     1783348.0
# December      349216.0
# January      1054289.0
# February      812457.0
# March         789835.0
# April         198025.0
# May            66303.0
# June          530431.0
# ...

# %% [markdown]
# ### Convert Non-Stationary to Stationary

# %%
df = df.diff().dropna()
df.plot(figsize = (10,10))
# Out:
# <AxesSubplot:xlabel='Months'>

# %% [markdown]
# ### Making a Time Series Stationary

# %%
pip install pmdarima

# %%
import pmdarima as pm
model=pm.auto_arima(df['Sales'],start_p=1,seasonal=True,D=1,trace=True,error_action='ignore',stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1463.885, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1481.518, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1473.686, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1460.550, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1479.519, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1462.266, Time=0.05 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=1461.878, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1457.644, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1459.261, Time=0.07 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1459.465, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1471.688, Time=0.03 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1461.273, Time=0.12 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 0.588 seconds

# %%
stepwise_model = pm.auto_arima(df, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=1076.180, Time=0.19 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1128.230, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1096.472, Time=0.14 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1075.525, Time=0.18 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=1090.141, Time=0.08 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=1076.589, Time=0.22 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=1076.205, Time=0.26 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=1079.679, Time=0.18 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=1078.067, Time=0.48 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=1107.949, Time=0.06 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=1075.628, Time=0.27 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=1091.289, Time=0.11 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=1077.018, Time=0.31 sec
# ...

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   47
# Model:               SARIMAX(0, 0, 1)   Log Likelihood                -726.822
# Date:                Mon, 20 Jun 2022   AIC                           1457.644
# Time:                        17:56:32   BIC                           1461.344
# Sample:                             0   HQIC                          1459.036
#                                  - 47
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.9614      0.094    -10.181      0.000      -1.146      -0.776
# sigma2      1.927e+12   6.68e-14   2.88e+25      0.000    1.93e+12    1.93e+12
# ...
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):              2164.66
# ...

# %%
model.plot_diagnostics(figsize = (12,12))

# %%
import statsmodels.api as sm

# %%
df.shape
# Out:
# (47, 1)

# %% [markdown]
# ### FIT the ARIMA model

# %%
from statsmodels.tsa.arima_model import ARIMA
model1 = sm.tsa.ARIMA(df.Sales[:43], order=(0,1,2))
model_fit = model1.fit()
print(model_fit.summary())
# Out:
# C:\Users\DS_USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DS_USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DS_USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Input In [69], in <cell line: 3>()
#       1 from statsmodels.tsa.arima_model import ARIMA
#       2 model1 = sm.tsa.ARIMA(df.Sales[:43], order=(0,1,2))
# ----> 3 model_fit = model1.fit()
# ...

# %% [markdown]
# ### Forecast

# %%
plt.figure(figsize=(10,10),dpi=300)
predicted_value = model_fit.predict(dynamic=False,alpha=0.05,plot_insample=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 2>()
#       1 plt.figure(figsize=(10,10),dpi=300)
# ----> 2 predicted_value = model_fit.predict(dynamic=False,alpha=0.05,plot_insample=True)
#       3 plt.show()
#
# NameError: name 'model_fit' is not defined

# %%
df
# Out:
#                                 Sales
# Months
# May         0 days 00:00:00.000064658
# June      -1 days +23:59:59.999770293
# July        0 days 00:00:00.000126582
# August      0 days 00:00:00.000007219
# September   0 days 00:00:00.000080385
# October     0 days 00:00:00.000574119
# November  -1 days +23:59:59.999668791
# December  -1 days +23:59:59.999797449
# January   -1 days +23:59:59.999877313
# February  -1 days +23:59:59.999894626
# March       0 days 00:00:00.000297378
# April       0 days 00:00:00.007704262
# May       -1 days +23:59:59.992693632
# June      -1 days +23:59:59.999498820
# July        0 days 00:00:00.000155818
# August      0 days 00:00:00.000406430
# September -1 days +23:59:59.999145598
# October     0 days 00:00:00.001274491
# November  -1 days +23:59:59.999206712
# December  -1 days +23:59:59.999988037
# January   -1 days +23:59:59.999865070
# February    0 days 00:00:00.000106383
# March     -1 days +23:59:59.999851696
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Months'>

# %%
df.columns.duplicated().any()
# Out:
# False

# %%
from matplotlib import pyplot as plt
plt.plot(model_fit.fittedvalues, color='blue')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 2>()
#       1 from matplotlib import pyplot as plt
# ----> 2 plt.plot(model_fit.fittedvalues, color='blue')
#
# NameError: name 'model_fit' is not defined

# %%
df_log = np.log(data['Sales'])
train_data, test_data = df_log[:int(len(df_log)*0.90)], df_log[int(len(df_log)*0.90):]
plt.figure(figsize=(15,6))
plt.grid(True)
plt.xlabel('Months')
plt.ylabel('Sales')
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()
# Out:
# C:\Users\DS_USER\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
from pmdarima.arima import auto_arima
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
test='adf',       # use adftest to find optimal 'd'
max_p=3, max_q=3, # maximum p and q
m=1,              # frequency of series
d=None,           # let model determine 'd'
seasonal=False,   # No Seasonality
start_P=0, 
D=0, 
trace=True,
error_action='ignore',  
suppress_warnings=True, 
stepwise=True)
print(model_autoARIMA.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [62], in <cell line: 2>()
#       1 from pmdarima.arima import auto_arima
# ----> 2 model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
#       3 test='adf',       # use adftest to find optimal 'd'
#       4 max_p=3, max_q=3, # maximum p and q
#       5 m=1,              # frequency of series
#       6 d=None,           # let model determine 'd'
#       7 seasonal=False,   # No Seasonality
#       8 start_P=0,
#       9 D=0,
#      10 trace=True,
#      11 error_action='ignore',
#      12 suppress_warnings=True,
#      13 stepwise=True)
#      14 print(model_autoARIMA.summary())
#
# ...

# %%
df_log
# Out:
# Months
# April        13.362409
# May          13.459280
# June         13.061773
# July         13.299985
# August       13.312000
# September    13.436869
# October      14.045757
# November     13.740464
# December     13.494133
# January      13.308781
# February     13.116522
# March        13.585426
# April        15.955427
# May          13.991445
# June         13.446156
# July         13.649454
# August       14.041393
# September    12.896784
# October      14.330438
# November     13.687937
# December     13.674254
# January      13.505360
# February     13.640823
# March        13.446497
# April              NaN
# May          12.608698
# June         12.968456
# July         13.123064
# August       13.047523
# September    13.374076
# October      14.272842
# November     14.394003
# December     12.763447
# January      13.868378
# February     13.607818
# March        13.579580
# April        12.196151
# May          11.101994
# June         13.181446
# ...

# %%
df_log = np.log(data['Sales'])
train_data, test_data = df_log[:int(len(df_log)*0.90)], df_log[int(len(df_log)*0.90):]
# Out:
# C:\Users\DS_USER\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as smapi
model = smapi.tsa.arima.ARIMA(train_data, order=(0,1,2))
# Out:
# C:\Users\DS_USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DS_USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DS_USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
#from statsmodels.tsa.arima_model import ARIMA
#model = sm.tsa.ARIMA(train_data, order=(0,1,2))
fitted = model.fit()
fitted.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Sales   No. Observations:                   43
# Model:                 ARIMA(0, 1, 2)   Log Likelihood                 -43.636
# Date:                Mon, 20 Jun 2022   AIC                             93.272
# Time:                        18:20:44   BIC                             98.485
# Sample:                             0   HQIC                            95.183
#                                  - 43
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6807      8.284     -0.082      0.935     -16.918      15.557
# ma.L2         -0.3186      2.790     -0.114      0.909      -5.787       5.149
# sigma2         0.4528      3.773      0.120      0.904      -6.942       7.848
# ...

# %%
fc = fitted.forecast(150, alpha=0.05)
# Out:
# C:\Users\DS_USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
fc
# Out:
# 43     13.718182
# 44     13.485693
# 45     13.485693
# 46     13.485693
# 47     13.485693
#          ...
# 188    13.485693
# 189    13.485693
# 190    13.485693
# 191    13.485693
# 192    13.485693
# Name: predicted_mean, Length: 150, dtype: float64
